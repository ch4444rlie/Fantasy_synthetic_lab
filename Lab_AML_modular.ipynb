# %% [markdown]
# # AML Lab (Modular Runner Notebook)
#
# This notebook keeps the original mission behavior, but makes navigation easier by delegating each mission to modular runner functions.

# %% [markdown]
# ## Quick Navigation
#
# - Mission 1: Generate synthetic transactions and visuals
# - Mission 2: Generate investigation documents
# - Mission 3: Run graph-based AML detection
# - Mission 4: Start interactive RAG investigation

# %%
from fantasy_aml.runners import run_mission_1, run_mission_2, run_mission_3, run_mission_4

# %% [markdown]
# ## Mission 1: Synthetic Data Generation

# %%
mission1_results = run_mission_1()
# Out:
# 🏰 FANTASY KINGDOM AML - MISSION 1: Synthetic Data Generation
# ...
#
# Step 1: Generating Transaction Data...
# Generated 3359 transactions (5.0% money laundering)
# K1C5 transactions: 518
#
# Step 2: Initializing Synthesis Engine...
#
# Step 3: Preparing Metadata...
# Prepared metadata for 14 columns
#
# Step 4: Synthesizing Data...
# Synthesizing with Gaussian Copula...
# Generated 1000 transactions
# Synthesizing with CTGAN...
# Generated 1000 transactions
# Synthesizing with TVAE...
# Generated 1000 transactions
# Synthesizing with Graph Network...
# Generated 1000 transactions, 500 nodes, 993 edges
#
# Step 5: Evaluating Quality...
#
# 🔍 Quality Assessment
#
# Evaluating GAUSSIAN_COPULA:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 14/14 [00:00<00:00, 544.37it/s]|
# Column Shapes Score: 94.0%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 91/91 [00:00<00:00, 363.22it/s]|
# Column Pair Trends Score: 85.81%
#
# Overall Score (Average): 89.9%
#
# ...

# %% [markdown]
# ## Mission 2: Document Forge

# %%
generated_docs = run_mission_2(csv_path='mission1_synthetic_data.csv')
generated_docs
# Out:
# 🏰 FANTASY KINGDOM AML - MISSION 2: Document Forging
# ...
#
# Target: Golden Griffin Trading Co., Goldweave Port, Valdris Kingdom
# Loaded Mission 1 data from mission1_synthetic_data.csv
# Ollama generation failed for whistleblower: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download
# Generated whistleblower report: ./mission2_documents\whistleblower_report_RG126225.pdf
# Generated bank statement: ./mission2_documents\bank_statement_571029.pdf
# Ollama generation failed for sar: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download
# Generated Suspicious Activity Report: ./mission2_documents\SAR_816751.pdf
#
# Generated Documents:
# 1. Whistleblower Report: whistleblower_report_RG126225.pdf
# 2. Bank Statement: bank_statement_571029.pdf
# 3. Suspicious Activity Report: SAR_816751.pdf
# Generated mission summary: ./mission2_documents\mission2_summary.txt
# ...

# %% [markdown]
# ## Mission 3: Prophecy Familiar (Graph AML Detection)

# %%
aml_system, mission3_results = run_mission_3(csv_path='mission1_synthetic_data.csv')
mission3_results
# Out:
# 🏰 Fantasy Kingdom AML Detection System
# ...
# Investigating corrupt syndicate in K1C5...
#
# Dataset Overview:
#   Total transactions: 1000
#   Money laundering cases: 155
#   K1C5 involvement: 184
# 🔨 Building transaction graphs...
# ✓ Created 26 temporal graph snapshots
# Sample graph - Nodes: torch.Size([371, 13]), Edges: torch.Size([2, 300]), Edge attr: torch.Size([300, 11])
#
# 🚀 Training GAE model...
# ...
# Epoch 1/50
#   Train Loss: 1.0407, AUC: 0.6890
#   Val Loss: 1.1431, AUC: 0.7105, PR-AUC: 0.3098
# Epoch 5/50
#   Train Loss: 0.8189, AUC: 0.7158
#   Val Loss: 0.9375, AUC: 0.7378, PR-AUC: 0.2960
# Epoch 10/50
#   Train Loss: 0.6855, AUC: 0.7370
#   Val Loss: 0.8462, AUC: 0.7559, PR-AUC: 0.3015
# Epoch 15/50
#   Train Loss: 0.6493, AUC: 0.7421
#   Val Loss: 0.7990, AUC: 0.7574, PR-AUC: 0.3002
# Epoch 20/50
#   Train Loss: 0.6141, AUC: 0.7403
#   Val Loss: 0.7627, AUC: 0.7554, PR-AUC: 0.2968
# Epoch 25/50
#   Train Loss: 0.6104, AUC: 0.7339
# ...

# %% [markdown]
# ## Mission 4: Oracle RAG Investigation

# %%
# Interactive cell. Type queries in the prompt and use 'exit' to stop.
chatbot = run_mission_4(
    transaction_csv='mission1_synthetic_data.csv',
    docs_folder='mission2_documents',
)
# Out:
# 🔮 **Initiating Valdris Financial Investigation System...**
# ...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ✓ **Initialized Arcane RAG System for Transaction and Document Analysis**
# 1️⃣ **Loading Enchanted Ledger from mission1_synthetic_data.csv...**
# ✓ **Loaded 44 ledger entries**
# 2️⃣ **Deciphering Ancient Scrolls from mission2_documents...**
# 📜 **Decoding bank_statement_571029.pdf...**
# 📜 **Decoding SAR_816751.pdf...**
# 📜 **Decoding whistleblower_report_RG126225.pdf...**
# ✓ **Processed 15 scroll fragments**
# ✓ **Indexed 59 artifacts with FAISS and BM25**
# 🏰 **Arcane Investigation Chamber Active**
# Type your query or 'exit' to close the chamber.
# Example Queries:
# - Average transaction amount in the database
# - Location indicated in the whistleblower report
# ...
